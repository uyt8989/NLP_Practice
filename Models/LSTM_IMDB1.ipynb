# %%
import re
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
vocab_size = 10000
max_len = 500

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
embedding_dim = 32
hidden_units = 32

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('GRU_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 313/313 [==============================] - ETA: 0s - loss: 0.4697 - acc: 0.7780
# Epoch 1: val_acc improved from -inf to 0.86120, saving model to GRU_model.h5
# 313/313 [==============================] - 88s 272ms/step - loss: 0.4697 - acc: 0.7780 - val_loss: 0.3279 - val_acc: 0.8612
# Epoch 2/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2775 - acc: 0.8909
# Epoch 2: val_acc improved from 0.86120 to 0.86320, saving model to GRU_model.h5
# 313/313 [==============================] - 84s 268ms/step - loss: 0.2775 - acc: 0.8909 - val_loss: 0.3178 - val_acc: 0.8632
# Epoch 3/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2279 - acc: 0.9142
# Epoch 3: val_acc improved from 0.86320 to 0.87100, saving model to GRU_model.h5
# 313/313 [==============================] - 84s 268ms/step - loss: 0.2279 - acc: 0.9142 - val_loss: 0.4089 - val_acc: 0.8710
# Epoch 4/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2001 - acc: 0.9262
# Epoch 4: val_acc improved from 0.87100 to 0.87720, saving model to GRU_model.h5
# 313/313 [==============================] - 84s 267ms/step - loss: 0.2001 - acc: 0.9262 - val_loss: 0.3011 - val_acc: 0.8772
# Epoch 5/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1741 - acc: 0.9370
# Epoch 5: val_acc improved from 0.87720 to 0.88020, saving model to GRU_model.h5
# 313/313 [==============================] - 84s 268ms/step - loss: 0.1741 - acc: 0.9370 - val_loss: 0.2956 - val_acc: 0.8802
# Epoch 6/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1561 - acc: 0.9437
# Epoch 6: val_acc improved from 0.88020 to 0.88560, saving model to GRU_model.h5
# 313/313 [==============================] - 84s 268ms/step - loss: 0.1561 - acc: 0.9437 - val_loss: 0.3012 - val_acc: 0.8856
# Epoch 7/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1489 - acc: 0.9485
# Epoch 7: val_acc did not improve from 0.88560
# 313/313 [==============================] - 84s 268ms/step - loss: 0.1489 - acc: 0.9485 - val_loss: 0.3343 - val_acc: 0.8850
# Epoch 8/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1370 - acc: 0.9516
# Epoch 8: val_acc did not improve from 0.88560
# 313/313 [==============================] - 84s 269ms/step - loss: 0.1370 - acc: 0.9516 - val_loss: 0.3682 - val_acc: 0.8852
# Epoch 9/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1317 - acc: 0.9545
# Epoch 9: val_acc did not improve from 0.88560
# 313/313 [==============================] - 84s 269ms/step - loss: 0.1317 - acc: 0.9545 - val_loss: 0.4550 - val_acc: 0.8678
# Epoch 9: early stopping

# %%
loaded_model = load_model('GRU_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 782/782 [==============================] - 34s 43ms/step - loss: 0.3430 - acc: 0.8696
#
#  테스트 정확도: 0.8696

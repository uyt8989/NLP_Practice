# %%
import re
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
vocab_size = 10000
max_len = 500

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('GRU_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 313/313 [==============================] - ETA: 0s - loss: 0.4695 - acc: 0.7847
# Epoch 1: val_acc improved from -inf to 0.85300, saving model to GRU_model.h5
# 313/313 [==============================] - 38s 98ms/step - loss: 0.4695 - acc: 0.7847 - val_loss: 0.3515 - val_acc: 0.8530
# Epoch 2/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2970 - acc: 0.8837
# Epoch 2: val_acc improved from 0.85300 to 0.86000, saving model to GRU_model.h5
# 313/313 [==============================] - 30s 96ms/step - loss: 0.2970 - acc: 0.8837 - val_loss: 0.3336 - val_acc: 0.8600
# Epoch 3/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2410 - acc: 0.9068
# Epoch 3: val_acc improved from 0.86000 to 0.88980, saving model to GRU_model.h5
# 313/313 [==============================] - 30s 96ms/step - loss: 0.2410 - acc: 0.9068 - val_loss: 0.2834 - val_acc: 0.8898
# Epoch 4/15
# 313/313 [==============================] - ETA: 0s - loss: 0.2041 - acc: 0.9244
# Epoch 4: val_acc did not improve from 0.88980
# 313/313 [==============================] - 30s 96ms/step - loss: 0.2041 - acc: 0.9244 - val_loss: 0.3772 - val_acc: 0.8724
# Epoch 5/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1794 - acc: 0.9338
# Epoch 5: val_acc improved from 0.88980 to 0.89320, saving model to GRU_model.h5
# 313/313 [==============================] - 30s 96ms/step - loss: 0.1794 - acc: 0.9338 - val_loss: 0.2765 - val_acc: 0.8932
# Epoch 6/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1574 - acc: 0.9445
# Epoch 6: val_acc did not improve from 0.89320
# 313/313 [==============================] - 30s 96ms/step - loss: 0.1574 - acc: 0.9445 - val_loss: 0.3739 - val_acc: 0.8768
# Epoch 7/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1426 - acc: 0.9494
# Epoch 7: val_acc did not improve from 0.89320
# 313/313 [==============================] - 30s 96ms/step - loss: 0.1426 - acc: 0.9494 - val_loss: 0.3307 - val_acc: 0.8876
# Epoch 8/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1212 - acc: 0.9592
# Epoch 8: val_acc did not improve from 0.89320
# 313/313 [==============================] - 30s 96ms/step - loss: 0.1212 - acc: 0.9592 - val_loss: 0.3507 - val_acc: 0.8756
# Epoch 9/15
# 313/313 [==============================] - ETA: 0s - loss: 0.1029 - acc: 0.9643
# Epoch 9: val_acc did not improve from 0.89320
# 313/313 [==============================] - 30s 96ms/step - loss: 0.1029 - acc: 0.9643 - val_loss: 0.3731 - val_acc: 0.8828
# Epoch 9: early stopping

# %%
loaded_model = load_model('GRU_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 782/782 [==============================] - 26s 32ms/step - loss: 0.3091 - acc: 0.8778
#
#  테스트 정확도: 0.8778
